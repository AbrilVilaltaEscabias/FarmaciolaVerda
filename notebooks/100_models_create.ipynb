# %%
import sys
sys.path.append("../src")

# %%
from domain import (
    Base,
    engine
)
# Out:
# DB_URL: postgresql://admin:admin123@localhost:5432/farmaciola_verda

# %%
Base.metadata.create_all(engine)
print(Base.metadata.tables.keys())
# Out:
# dict_keys(['recipe_category', 'wish_list_recipes', 'wish_list_plant', 'plant_property', 'user', 'user_profile', 'recipe', 'category', 'ingredient', 'list_ingredient', 'property'])
