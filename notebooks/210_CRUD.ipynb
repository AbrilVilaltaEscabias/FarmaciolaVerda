# %%
import sys
sys.path.append("../src")

# %%
from sqlalchemy.orm import Session
from domain import User, Category, Recipe, Ingredient, Base, UserRepository, engine, Session, UnitOfWork

Base.metadata.create_all(engine)
# Out:
# DB_URL: postgresql://admin:admin123@localhost:5432/farmaciola_verda

# %%
id_user = 0 # Variable per a guardar l'id
id_category = 0 # Variable per a guardar l'id
id_recipe = 0 # Variable per a guardar l'id
id_ingredint = 0 # Variable per a guardar l'id

# %% [markdown]
# ### CREATE

# %% [markdown]
# #### User

# %%
with UnitOfWork(Session) as uow:
    u = User(user_name="joan", email="joan@test.com", password="1234")
    uow.users.add(u)
    uow.commit()
    id_user = u.id
    print("ADD OK:", id_user)
# Out:
# ADD OK: 21

# %% [markdown]
# #### Recipe

# %%
with UnitOfWork(Session) as uow:
    r = Recipe(name="Ginger Infusion", duration=10, step_by_step="1. Boil water. 2. Peel and slice fresh ginger. 3. Add ginger to the water. 4. Simmer for 10 minutes. 5. Strain and serve.", description="A warming and energizing infusion with anti-inflammatory properties.")
    uow.recipes.add(r)
    uow.commit()
    id_recipe = r.id
    print("ADD OK:", id_recipe)
# Out:
# ADD OK: 12

# %% [markdown]
# #### Category

# %%
with UnitOfWork(Session) as uow:
    c = Category(name="Migrains")
    uow.categories.add(c)
    uow.commit()
    id_category = c.id
    print("ADD OK:", id_category)
# Out:
# ADD OK: 12

# %% [markdown]
# #### Ingredient

# %%
with UnitOfWork(Session) as uow:
    i = Ingredient(scientific_name="Zingiber officinale", common_name="Gingebre", family="Zingiberaceae", description="Planta medicinal amb propietats antiinflamatòries i digestives", country_origin="Àsia", type="Arrel")
    uow.ingredients.add(i)
    uow.commit()
    id_ingredint = i.id
    print("ADD OK:", id_ingredint)
# Out:
# ADD OK: 12

# %% [markdown]
# ### READ

# %% [markdown]
# #### User

# %%
with UnitOfWork(Session) as uow:
    trobat = uow.users.get(id_user)
    print("GET OK:", trobat.user_name)
# Out:
# GET OK: joan

# %%
with UnitOfWork(Session) as uow:
    tots = uow.users.get_all()
    print("GET ALL OK:", len(tots))
# Out:
# GET ALL OK: 13

# %% [markdown]
# #### Recipe

# %%
with UnitOfWork(Session) as uow:
    trobat = uow.recipes.get(id_recipe)
    print("GET OK:", trobat.name)
# Out:
# GET OK: Ginger Infusion

# %%
with UnitOfWork(Session) as uow:
    tots = uow.recipes.get_all()
    print("GET ALL OK:", len(tots))
# Out:
# GET ALL OK: 11

# %% [markdown]
# #### Category

# %%
with UnitOfWork(Session) as uow:
    trobat = uow.categories.get(id_category)
    print("GET OK:", trobat.name)
# Out:
# GET OK: Migrains

# %%
with UnitOfWork(Session) as uow:
    tots = uow.categories.get_all()
    print("GET ALL OK:", len(tots))
# Out:
# GET ALL OK: 11

# %% [markdown]
# #### Ingredient

# %%
with UnitOfWork(Session) as uow:
    trobat = uow.ingredients.get(id_ingredint)
    print("GET OK:", trobat.common_name)
# Out:
# GET OK: Gingebre

# %%
with UnitOfWork(Session) as uow:
    tots = uow.ingredients.get_all()
    print("GET ALL OK:", len(tots))
# Out:
# GET ALL OK: 11

# %% [markdown]
# ### UPDATE

# %% [markdown]
# #### User

# %%
with UnitOfWork(Session) as uow:

    trobat = uow.users.get(id_user)
    trobat.alias = "joan_nou"

    uow.users.update(trobat)
    uow.commit()
    print("UPDATE OK:", uow.users.get(id).alias)
# Out:
# UPDATE OK: joan

# %% [markdown]
# #### Recipe

# %%
with UnitOfWork(Session) as uow:

    trobat = uow.recipes.get(id_recipe)
    trobat.duration = 9

    uow.recipes.update(trobat)
    uow.commit()
    print("UPDATE OK:", uow.recipes.get(id_recipe).duration)
# Out:
# UPDATE OK: 9

# %% [markdown]
# #### Category

# %%
with UnitOfWork(Session) as uow:

    trobat = uow.categories.get(id_category)
    trobat.name = "Ginger Infusion nou"

    uow.categories.update(trobat)
    uow.commit()
    print("UPDATE OK:", uow.categories.get(id_category).name)
# Out:
# UPDATE OK: Ginger Infusion nou

# %% [markdown]
# #### Ingredients

# %%
with UnitOfWork(Session) as uow:

    trobat = uow.ingredients.get(id_ingredint)
    trobat.isoptional = "False"

    uow.ingredients.update(trobat)
    uow.commit()
    print("UPDATE OK:", uow.ingredients.get(id_ingredint).isoptional)
# Out:
# UPDATE OK: False

# %% [markdown]
# ### DELETE

# %% [markdown]
# #### User

# %%
with UnitOfWork(Session) as uow:
    
    uow.users.delete(id_user)
    uow.commit()
    print("DELETE OK:", uow.users.get(id_user))  # Ha de ser None
# Out:
# DELETE OK: None

# %% [markdown]
# #### Recipe

# %%
with UnitOfWork(Session) as uow:
    
    uow.recipes.delete(id_recipe)
    uow.commit()
    print("DELETE OK:", uow.recipes.get(id_recipe))  # Ha de ser None
# Out:
# DELETE OK: None

# %% [markdown]
# #### Categories

# %%
with UnitOfWork(Session) as uow:
    
    uow.categories.delete(id_category)
    uow.commit()
    print("DELETE OK:", uow.categories.get(id_category))  # Ha de ser None
# Out:
# DELETE OK: None

# %% [markdown]
# #### Ingredients

# %%
with UnitOfWork(Session) as uow:
    
    uow.ingredients.delete(id_ingredint)
    uow.commit()
    print("DELETE OK:", uow.ingredients.get(id_ingredint))  # Ha de ser None
# Out:
# DELETE OK: None
