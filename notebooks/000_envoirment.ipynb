# %%
import sys
sys.path.append("../src")

# %%
from domain import (
    ENVIROMENT, 
    DB_URL)

(ENVIROMENT, DB_URL)
# Out:
# DB_URL: postgresql+psycopg2://admin:admin123@localhost/farmaciola_verda
# ('production',
#  'postgresql+psycopg2://admin:admin123@localhost/farmaciola_verda')
