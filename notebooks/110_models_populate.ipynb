# %%
import sys
from sqlalchemy import insert, select
sys.path.append("../src")

# %%
from domain import (
    User,
    UserProfile,
    Recipe,
    Category,
    Ingredient,
    ListIngredients,
    Property,
    recipe_category_table,
    wish_list_recipes_table,
    wish_list_plant_table,
    plant_property_table,
    Session,
    Base,
    engine
)

print(engine.url)
# Out:
# DB_URL: postgresql://admin:admin123@localhost:5432/farmaciola_verda
# postgresql://admin:***@localhost:5432/farmaciola_verda

# %%
with Session() as session:
    
    # ── USERS ────────────────────────────────────────────────────────────────
    users = [
        User(user_name="joan_puig", alias="Joan", email="joan@mail.com", password="1234"),
        User(user_name="maria_vila", alias="Maria", email="maria@mail.com", password="1234"),
        User(user_name="pere_mas", alias="Pere", email="pere@mail.com", password="1234"),
        User(user_name="anna_font", alias="Anna", email="anna@mail.com", password="1234"),
        User(user_name="lluc_ros", alias="Lluc", email="lluc@mail.com", password="1234"),
        User(user_name="marta_sol", alias="Marta", email="marta@mail.com", password="1234"),
        User(user_name="pau_vidal", alias="Pau", email="pau@mail.com", password="1234"),
        User(user_name="clara_pi", alias="Clara", email="clara@mail.com", password="1234"),
        User(user_name="marc_riu", alias="Marc", email="marc@mail.com", password="1234"),
        User(user_name="laia_bosc", alias="Laia", email="laia@mail.com", password="1234"),
    ]
    session.add_all(users)
  # per obtenir els ids generats
    session.commit()

    for user in session.scalars(select(User)).all():
      print(user.user_name)
# Out:
# joan_puig
# maria_vila
# pere_mas
# anna_font
# lluc_ros
# marta_sol
# pau_vidal
# clara_pi
# marc_riu
# laia_bosc

# %%
with Session() as session:
    # ── USER PROFILES ────────────────────────────────────────────────────────
    profiles = [
        UserProfile(bio="M'agraden les plantes medicinals", img="img1.jpg", id_user=users[0].id),
        UserProfile(bio="Herbolari amateur", img="img2.jpg", id_user=users[1].id),
        UserProfile(bio="Cuiner de remeis naturals", img="img3.jpg", id_user=users[2].id),
        UserProfile(bio="Estudiant de botànica", img="img4.jpg", id_user=users[3].id),
        UserProfile(bio="Apassionat de la natura", img="img5.jpg", id_user=users[4].id),
        UserProfile(bio="Jardinera i herbòloga", img="img6.jpg", id_user=users[5].id),
        UserProfile(bio="Investigador de plantes", img="img7.jpg", id_user=users[6].id),
        UserProfile(bio="Naturalista", img="img8.jpg", id_user=users[7].id),
        UserProfile(bio="Metge naturista", img="img9.jpg", id_user=users[8].id),
        UserProfile(bio="Apotecari modern", img="img10.jpg", id_user=users[9].id),
    ]
    session.add_all(profiles)

# %%
# ── CATEGORIES ───────────────────────────────────────────────────────────
categories = [
    Category(name="Digestiva"),
    Category(name="Relaxant"),
    Category(name="Antiinflamatòria"),
    Category(name="Immunoestimulant"),
    Category(name="Antioxidant"),
    Category(name="Depurativa"),
    Category(name="Energitzant"),
    Category(name="Antiespasmòdica"),
    Category(name="Cicatritzant"),
    Category(name="Expectorant"),
]
    
session.add_all(categories)
session.flush()

# %%
# ── INGREDIENTS ──────────────────────────────────────────────────────────
ingredients = [
    Ingredient(scientific_name="Matricaria chamomilla", common_name="Camamilla", family="Asteraceae", description="Planta medicinal calmant", country_origin="Europa", type="Flor"),
    Ingredient(scientific_name="Mentha piperita", common_name="Menta", family="Lamiaceae", description="Refrescant i digestiva", country_origin="Europa", type="Fulla"),
    Ingredient(scientific_name="Lavandula angustifolia", common_name="Lavanda", family="Lamiaceae", description="Relaxant i aromàtica", country_origin="Mediterrània", type="Flor"),
    Ingredient(scientific_name="Echinacea purpurea", common_name="Equinàcia", family="Asteraceae", description="Estimulant del sistema immunitari", country_origin="Amèrica del Nord", type="Arrel"),
    Ingredient(scientific_name="Zingiber officinale", common_name="Gingebre", family="Zingiberaceae", description="Antiinflamatori i digestiu", country_origin="Àsia", type="Arrel"),
    Ingredient(scientific_name="Hypericum perforatum", common_name="Hipèric", family="Hypericaceae", description="Antidepressiu natural", country_origin="Europa", type="Fulla"),
    Ingredient(scientific_name="Valeriana officinalis", common_name="Valeriana", family="Caprifoliaceae", description="Sedant i relaxant", country_origin="Europa", type="Arrel"),
    Ingredient(scientific_name="Rosmarinus officinalis", common_name="Romaní", family="Lamiaceae", description="Estimulant i antioxidant", country_origin="Mediterrània", type="Fulla"),
    Ingredient(scientific_name="Melissa officinalis", common_name="Melissa", family="Lamiaceae", description="Calmant i digestiva", country_origin="Europa", type="Fulla"),
    Ingredient(scientific_name="Thymus vulgaris", common_name="Farigola", family="Lamiaceae", description="Antisèptic i expectorant", country_origin="Mediterrània", type="Fulla"),
]
session.add_all(ingredients)
session.flush()

# %%
# ── PROPERTIES ───────────────────────────────────────────────────────────
properties = [
    Property(name="Calmant"),
    Property(name="Digestiva"),
    Property(name="Antiinflamatòria"),
    Property(name="Antisèptica"),
    Property(name="Antioxidant"),
    Property(name="Immunoestimulant"),
    Property(name="Sedant"),
    Property(name="Expectorant"),
    Property(name="Cicatritzant"),
    Property(name="Energitzant"),
]
session.add_all(properties)
session.flush()

# %%
# ── RECIPES ──────────────────────────────────────────────────────────────
recipes = [
    Recipe(name="Infusió de camamilla", duration=10, step_by_step="1. Bullir aigua. 2. Afegir camamilla. 3. Reposar 5 min.",description="Infusió relaxant"),
    Recipe(name="Xarop de gingebre", duration=30, step_by_step="1. Bullir gingebre. 2. Afegir mel. 3. Filtrar.", description="Per a la tos"),
    Recipe(name="Oli de lavanda", duration=60, step_by_step="1. Macerar lavanda en oli. 2. Filtrar.", description="Per relaxar"),
    Recipe(name="Tintura d'equinàcia", duration=120, step_by_step="1. Macerar en alcohol. 2. Filtrar. 3. Envasar.", description="Immunoestimulant"),
    Recipe(name="Infusió de menta", duration=10, step_by_step="1. Bullir aigua. 2. Afegir menta. 3. Reposar.", description="Digestiva"),
    Recipe(name="Crema de romaní", duration=45, step_by_step="1. Infusionar romaní. 2. Barrejar amb crema base.", description="Antiinflamatòria"),
    Recipe(name="Infusió de valeriana", duration=15, step_by_step="1. Bullir aigua. 2. Afegir valeriana. 3. Reposar 10 min.", description="Per dormir"),
    Recipe(name="Xarop de farigola", duration=25, step_by_step="1. Bullir farigola. 2. Afegir mel. 3. Filtrar.", description="Per a la gola"),
    Recipe(name="Infusió de melissa", duration=10, step_by_step="1. Bullir aigua. 2. Afegir melissa. 3. Reposar.", description="Calmant"),
    Recipe(name="Càpsula d'hipèric", duration=5, step_by_step="1. Triturar hipèric sec. 2. Encapsular.", description="Antidepressiu"),
]
session.add_all(recipes)
session.flush()

# %%
# ── LIST INGREDIENTS (1 to M amb camps extra) ────────────────────────────
list_ingredients = [
    ListIngredients(id_recipe=recipes[0].id, id_plant=ingredients[0].id, quantity="1 cullerada", isoptional=False),
    ListIngredients(id_recipe=recipes[0].id, id_plant=ingredients[2].id, quantity="1/2 cullerada", isoptional=True),
    ListIngredients(id_recipe=recipes[1].id, id_plant=ingredients[4].id, quantity="50g", isoptional=False),
    ListIngredients(id_recipe=recipes[2].id, id_plant=ingredients[2].id, quantity="100g", isoptional=False),
    ListIngredients(id_recipe=recipes[3].id, id_plant=ingredients[3].id, quantity="200g", isoptional=False),
    ListIngredients(id_recipe=recipes[4].id, id_plant=ingredients[1].id, quantity="2 cullerades", isoptional=False),
    ListIngredients(id_recipe=recipes[5].id, id_plant=ingredients[7].id, quantity="30g", isoptional=False),
    ListIngredients(id_recipe=recipes[6].id, id_plant=ingredients[6].id, quantity="1 cullerada", isoptional=False),
    ListIngredients(id_recipe=recipes[7].id, id_plant=ingredients[9].id, quantity="40g", isoptional=False),
    ListIngredients(id_recipe=recipes[8].id, id_plant=ingredients[8].id, quantity="1 cullerada", isoptional=False),
]
session.add_all(list_ingredients)
session.flush()

# %%
# ── RECIPE - CATEGORY TABLE (N to M) ───────────────────────────────────────
session.execute(insert(recipe_category_table), [
    {"id_recipe": recipes[0].id, "id_category": categories[1].id},
    {"id_recipe": recipes[1].id, "id_category": categories[0].id},
    {"id_recipe": recipes[2].id, "id_category": categories[1].id},
    {"id_recipe": recipes[3].id, "id_category": categories[3].id},
    {"id_recipe": recipes[4].id, "id_category": categories[0].id},
    {"id_recipe": recipes[5].id, "id_category": categories[2].id},
    {"id_recipe": recipes[6].id, "id_category": categories[1].id},
    {"id_recipe": recipes[7].id, "id_category": categories[9].id},
    {"id_recipe": recipes[8].id, "id_category": categories[1].id},
    {"id_recipe": recipes[9].id, "id_category": categories[1].id},
])
session.add_all(list_ingredients)
session.flush()

# %%
# ── WISH LIST - RECIPES TABLE (N to M) ───────────────────────────────────
session.execute(insert(wish_list_recipes_table), [
    {"id_recipe": recipes[0].id, "id_user": users[0].id},
    {"id_recipe": recipes[1].id, "id_user": users[1].id},
    {"id_recipe": recipes[2].id, "id_user": users[2].id},
    {"id_recipe": recipes[3].id, "id_user": users[3].id},
    {"id_recipe": recipes[4].id, "id_user": users[4].id},
    {"id_recipe": recipes[5].id, "id_user": users[5].id},
    {"id_recipe": recipes[6].id, "id_user": users[6].id},
    {"id_recipe": recipes[7].id, "id_user": users[7].id},
    {"id_recipe": recipes[8].id, "id_user": users[8].id},
    {"id_recipe": recipes[9].id, "id_user": users[9].id},
])
session.add_all(list_ingredients)
session.flush()

# %%
# ── WISH LIST - PLANT TABLE (N to M) ─────────────────────────────────────
session.execute(insert(wish_list_plant_table), [
    {"id_plant": ingredients[0].id, "id_user": users[0].id},
    {"id_plant": ingredients[1].id, "id_user": users[1].id},
    {"id_plant": ingredients[2].id, "id_user": users[2].id},
    {"id_plant": ingredients[3].id, "id_user": users[3].id},
    {"id_plant": ingredients[4].id, "id_user": users[4].id},
    {"id_plant": ingredients[5].id, "id_user": users[5].id},
    {"id_plant": ingredients[6].id, "id_user": users[6].id},
    {"id_plant": ingredients[7].id, "id_user": users[7].id},
    {"id_plant": ingredients[8].id, "id_user": users[8].id},
    {"id_plant": ingredients[9].id, "id_user": users[9].id},
])
session.add_all(list_ingredients)
session.flush()

# %%
# ── PLANT - PROPERTY TABLE (N to M) ──────────────────────────────────────
session.execute(insert(plant_property_table), [
    {"id_plant": ingredients[0].id, "id_property": properties[0].id},
    {"id_plant": ingredients[1].id, "id_property": properties[1].id},
    {"id_plant": ingredients[2].id, "id_property": properties[0].id},
    {"id_plant": ingredients[3].id, "id_property": properties[5].id},
    {"id_plant": ingredients[4].id, "id_property": properties[2].id},
    {"id_plant": ingredients[5].id, "id_property": properties[0].id},
    {"id_plant": ingredients[6].id, "id_property": properties[6].id},
    {"id_plant": ingredients[7].id, "id_property": properties[4].id},
    {"id_plant": ingredients[8].id, "id_property": properties[0].id},
    {"id_plant": ingredients[9].id, "id_property": properties[7].id},
])
session.add_all(list_ingredients)
session.flush()
session.commit()
