# %%
import sys
sys.path.append("../src")

# %%
from domain import  Base, engine

(Base, engine)
# Out:
# DB_URL: postgresql://admin:admin123@localhost:5432/farmaciola_verda
# (domain.db.Base,
#  Engine(postgresql://admin:***@localhost:5432/farmaciola_verda))
