# %%
import sys
sys.path.append("../src")

# %%
from domain import (
    Session,
    engine, 
    User,
    UserRepository,
    )
# Out:
# DB_URL: postgresql://admin:admin123@localhost:5432/farmaciola_verda

# %%
session = Session()

manela_no_vull_currar_per_voste = User()
manela_no_vull_currar_per_voste.user_name = "ManelaNoVullCurrarPerVoste"
manela_no_vull_currar_per_voste.email = "ManelaNoVullCurrarPerVoste@gmail.com"
manela_no_vull_currar_per_voste.password = "Manela1234"

user_repository = UserRepository(session)
user_repository.add(manela_no_vull_currar_per_voste)

session.commit()

# %%
manela_no_vull_currar_per_voste.id
# Out:
# 1

# %%
class UnitOfWork():
    def __init__(self, Session):
        self.Session = Session

    def __enter__(self):
        self.session = Session()
    
    def __exit__(self, exc_type, exc, tb):
        if exc is not None:
            self.session.rollback()
        else:
            self.session.commit()

with UnitOfWork(Session) as uow:
    # es creen els repositoris
    # es desenvolupa la logica de l'empresa
    ...
